# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from PIL import Image
from scipy import sparse
import cv2
from pymatreader import read_mat

# from extract_graph import dic_to_sparse
from util.sys import get_path, shift_skeleton
from plotutil import (
    show_im,
    overlap,
    show_im_rgb,
    plot_nodes,
    plot_nodes_from_list,
    plot_t_tp1,
)
from extract_graph import (
    generate_graph_tab_from_skeleton,
    generate_nx_graph_from_skeleton,
    generate_skeleton,
    clean,
)
import networkx as nx
from node_id import (
    second_identification,
    whole_movement_identification,
    first_identification,
    relabel_nodes,
    clean_nodes,
    orient,
)
from extract_graph import (
    dic_to_sparse,
    from_sparse_to_graph,
    generate_nx_graph,
    prune_graph,
    from_nx_to_tab,
    from_nx_to_tab_matlab,
    sparse_to_doc,
    connections_pixel_list_to_tab,
    transform_list,
)
from sparse_util import dilate, zhangSuen
from realign import realign, reconnect
from util.sys import get_path
import pandas as pd
from datetime import datetime, timedelta
import ast
from time import time
import os

# %%
0.013998270034790039 * 18000
# Out:
# 251.9688606262207

# %%
plate = 27
directory = (
    "//sun.amolf.nl/shimizu-data/home-folder/oyartegalvez/Drive_AMFtopology/PRINCE"
)
listdir = os.listdir(directory)
list_dir_interest = [
    name
    for name in listdir
    if name.split("_")[-1] == f'Plate{0 if plate<10 else ""}{plate}'
]
ss = [name.split("_")[0] for name in list_dir_interest]
ff = [name.split("_")[1] for name in list_dir_interest]
dates_datetime = [
    datetime(
        year=int(ss[i][:4]),
        month=int(ss[i][4:6]),
        day=int(ss[i][6:8]),
        hour=int(ff[i][0:2]),
        minute=int(ff[i][2:4]),
    )
    for i in range(len(list_dir_interest))
]
dates_datetime.sort()
dates_datetime_chosen = dates_datetime[1:6]
dates = [
    f'{0 if date.month<10 else ""}{date.month}{0 if date.day<10 else ""}{date.day}_{0 if date.hour<10 else ""}{date.hour}{0 if date.minute<10 else ""}{date.minute}'
    for date in dates_datetime_chosen
]
mat_skels = [read_mat(get_path(date, plate, True))["skel"] for date in dates]
dic_skels = [dic_to_sparse(mat_skel) for mat_skel in mat_skels]
skeleton_docs = [sparse_to_doc(sparse_skel) for sparse_skel in dic_skels]

# %%
def find_common_group_nodes(
    Sa, Sb, degree3_nodesa, degree3_nodesb, posa, posb, R0, t0, window=500, maxdist=50
):
    common_nodes_a = []
    common_nodes_b = []
    common_centroida = []
    common_centroidb = []
    t = time()
    posarottrans = {
        key: np.round(
            np.transpose(np.dot(R0, np.transpose(np.array(posa[key]))) + t0)
        ).astype(np.int)
        for key in degree3_nodesa
    }
    print("rotating translating", time() - t)
    for node in degree3_nodesa:
        t = time()
        posanchor = posarottrans[node]
        potential_surroundinga = Sa[
            posanchor[0] - 2 * window : posanchor[0] + 2 * window,
            posanchor[1] - 2 * window : posanchor[1] + 2 * window,
        ]
        potential_surroundingb = Sb[
            posanchor[0] - 2 * window : posanchor[0] + 2 * window,
            posanchor[1] - 2 * window : posanchor[1] + 2 * window,
        ]
        #         print("candidates",len(potential_surroundinga.data))
        #         print("finding_potential_surrounding",time()-t)
        t = time()
        surrounding_nodesa = [
            node
            for node in potential_surroundinga.data
            if (
                posanchor[0] - window
                < posarottrans[int(node)][0]
                < posanchor[0] + window
                and posanchor[1] - window
                < posarottrans[int(node)][1]
                < posanchor[1] + window
            )
        ]
        surrounding_nodesb = [
            node
            for node in potential_surroundingb.data
            if (
                posanchor[0] - window < posb[int(node)][0] < posanchor[0] + window
                and posanchor[1] - window < posb[int(node)][1] < posanchor[1] + window
            )
        ]
        #         print("finding_surrounding",time()-t)
        t = time()
        if len(surrounding_nodesa) == len(surrounding_nodesb):
            possurroundinga = [posarottrans[node] for node in surrounding_nodesa]
            possurroundingb = [posb[node] for node in surrounding_nodesb]
            centroida = np.mean(possurroundinga, axis=0)
            centroidb = np.mean(possurroundingb, axis=0)
            if np.linalg.norm(centroida - centroidb) <= maxdist:
                common_centroida.append(centroida)
                common_centroidb.append(centroidb)
    return (common_centroida, common_centroidb)


def realign2(
    skeleton1, skeleton2, convergence_threshold, window=500, maxdist=50, save=""
):
    converged = False
    tim = time()
    nx_graphA, posA = generate_nx_graph_from_skeleton(skeleton1)
    nx_graphB, posB = generate_nx_graph_from_skeleton(skeleton2)
    print("generate_nx_graph_from_skeleton, t=", tim - time())
    tim = time()
    t0 = np.array([0, 0])
    R0 = np.identity(2)
    degree3_nodesa = [node for node in nx_graphA if nx_graphA.degree(node) == 3]
    degree3_nodesb = [node for node in nx_graphB if nx_graphB.degree(node) == 3]
    print("lennodes=", len(degree3_nodesa))
    Sa = sparse.csr_matrix((22000, 46000))
    Sb = sparse.csr_matrix((22000, 46000))
    for node in degree3_nodesa:
        Sa[posA[node][0], posA[node][1]] = node
    for node in degree3_nodesb:
        Sb[posB[node][0], posB[node][1]] = node
    while not converged:
        listeA, listeB = find_common_group_nodes(
            Sa,
            Sb,
            degree3_nodesa,
            degree3_nodesb,
            posA,
            posB,
            R0,
            t0,
            maxdist=maxdist,
            window=window,
        )
        H = np.dot(
            np.transpose(np.array(listeA) - np.mean(listeA, axis=0)),
            np.array(listeB) - np.mean(listeB, axis=0),
        )
        U, S, V = np.linalg.svd(H)
        R = np.dot(V, np.transpose(U))
        t = np.mean(listeB, axis=0) - np.dot(R, np.mean(listeA, axis=0))
        print("number_common_nodes_found :", len(listeA))
        if np.linalg.norm(t) <= convergence_threshold:
            converged = True
        R0 = np.dot(R, R0)
        t0 = t + t0
    print("Find R and T, t=", tim - time())
    tim = time()
    skeleton_transformed = transform_skeleton(skeleton1, R0, t0)
    skeleton_transformed = dilate(skeleton_transformed)
    skeleton_transformed = zhangSuen(skeleton_transformed)
    print("transform, dilate and thin, t=", tim - time())
    tim = time()
    if len(save) >= 0:
        from_nx_to_tab(*generate_nx_graph_from_skeleton(skeleton_transformed)).to_csv(
            save + "_raw_aligned_skeleton.csv"
        )
        np.savetxt(save + "rot.txt", R0)
        np.savetxt(save + "trans.txt", t0)
    print("R0=", R0, "t0=", t0)
    return skeleton_transformed

# %%
def transform_skeleton(skeleton_doc, Rot, trans):
    transformed_skeleton = {}
    transformed_keys = np.round(
        np.transpose(np.dot(Rot, np.transpose(np.array(list(skeleton_doc.keys())))))
        + trans
    ).astype(np.int)
    i = 0
    for pixel in list(transformed_keys):
        i += 1
        transformed_skeleton[(pixel[0], pixel[1])] = 1
    return transformed_skeleton

# %%
S = sparse.csr_matrix((22000, 46000))
S[12000:14000, 12000:14000] = 1

# %%
S.data
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
import cProfile

cProfile.run("S[12000:14000,12000:14000]")

# %%
r = realign2(skeleton_docs[4], skeleton_docs[3], 2, save="Data/", maxdist=70)
# Out:
# generate_nx_graph_from_skeleton, t= -586.73597240448
# lennodes= 13604
# rotating translating 0.16901159286499023
# number_common_nodes_found : 328
# rotating translating 0.2030162811279297
# number_common_nodes_found : 402
# rotating translating 0.18901276588439941
# number_common_nodes_found : 480
# rotating translating 0.1980135440826416
# number_common_nodes_found : 635
# rotating translating 0.18399858474731445
# number_common_nodes_found : 743
# rotating translating 0.1960141658782959
# number_common_nodes_found : 834
# rotating translating 0.1940152645111084
# number_common_nodes_found : 832
# rotating translating 0.20001506805419922
# number_common_nodes_found : 872
# rotating translating 0.19201445579528809
# number_common_nodes_found : 904
# Find R and T, t= -203.0311245918274
# transform, dilate and thin, t= -374.64126110076904
# R0= [[ 0.99999879  0.00155542]
#  [-0.00155542  0.99999879]] t0= [ -2.50883403 -72.90254211]

# %%
r0 = realign(skeleton_docs[4], nx_graph_pivot, pos_pivot, 2, save="Data/", maxdist=150)
# Out:
# number_common_nodes_found : 356
# number_common_nodes_found : 465
# number_common_nodes_found : 489
# 992004 993235
# 995666 995743
# 133466 3100
# 1376 924
# 606 475
# 410 375
# 306 273
# 216 196
# 169 125
# 122 105
# 90 69
# 72 58
# 60 45
# 48 36
# 38 27
# 27 21
# 22 16
# 15 11
# 9 6
# 3 0
# 0 0
# R0= [[ 9.99999527e-01 -9.72716200e-04]
#  [ 9.72716200e-04  9.99999527e-01]] t0= [42.25170203  6.08798379]

# %%
r1 = realign(skeleton_docs[4], nx_graph_pivot, pos_pivot, 2, save="Data/", maxdist=50)
# Out:
# number_common_nodes_found : 290
# number_common_nodes_found : 435
# number_common_nodes_found : 454
# number_common_nodes_found : 465
# 992012 993234
# 995675 995706
# 133613 3119
# 1377 925
# 612 475
# 410 375
# 306 273
# 216 196
# 169 125
# 122 105
# 90 69
# 72 58
# 60 45
# 48 36
# 38 27
# 27 21
# 22 16
# 15 11
# 9 6
# 3 0
# 0 0
# R0= [[ 0.99999924 -0.00123398]
#  [ 0.00123398  0.99999924]] t0= [47.7829256   3.93269705]

# %%
def make_sparse(dico):
    dim = (20800, 46000)
    skel = sparse.dok_matrix(dim, dtype=bool)
    for key in dico.keys():
        skel[key] = dico[key]
    return skel

# %%
skeletons = [make_sparse(skeleton_docs[0]), make_sparse(r0), make_sparse(r1)]

# %%
from plotutil import plot_t_tp1, compress_skeleton

factor = 5
final_pictures = [
    compress_skeleton(skeletons[i], factor) >= 1 for i in range(len(skeletons))
]

# %%
plot_t_tp1(
    [],
    [],
    None,
    None,
    final_pictures[0],
    final_pictures[2],
    compress=5,
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close("all")

# %%
r = realign(skeleton_docs[4], nx_graph_pivot, pos_pivot, 2, save="Data/", maxdist=30)
# Out:
# number_common_nodes_found : 55
# number_common_nodes_found : 170
# number_common_nodes_found : 417
# number_common_nodes_found : 453
# 991937 993213
# 995616 995688
# 133668 3119
# 1389 929
# 613 475
# 410 375
# 306 273
# 216 196
# 169 125
# 122 105
# 88 67
# 72 58
# 60 45
# 48 36
# 38 27
# 27 21
# 22 16
# 15 11
# 9 6
# 3 0
# 0 0
# R0= [[ 0.99999923 -0.00124197]
#  [ 0.00124197  0.99999923]] t0= [48.09796892  3.71029006]

# %%
r = realign(skeleton_docs[4], nx_graph_pivot, pos_pivot, 2, save="Data/", maxdist=40)
# Out:
# number_common_nodes_found : 209
# number_common_nodes_found : 405
# number_common_nodes_found : 450
# number_common_nodes_found : 458
# 991983 993211
# 995655 995687
# 133685 3099
# 1373 930
# 619 476
# 410 375
# 306 273
# 216 196
# 169 125
# 122 105
# 90 69
# 72 58
# 60 45
# 48 36
# 38 27
# 27 21
# 22 16
# 15 11
# 9 6
# 3 0
# 0 0
# R0= [[ 0.99999925 -0.00122743]
#  [ 0.00122743  0.99999925]] t0= [47.84393103  4.08633907]

# %%
cProfile.run(
    "[realign2(skeleton_docs[i],nx_graph_pivot,pos_pivot,2) for i in range(1,len(skeleton_docs))]"
)
# Out:
# number_common_nodes_found : 475 [[ 1.00000000e+00  2.86863865e-05]
#  [-2.86863865e-05  1.00000000e+00]] [15.49591566 -2.72514169]
# number_common_nodes_found : 562 [[ 1.0000000e+00  9.8598479e-06]
#  [-9.8598479e-06  1.0000000e+00]] [ 0.02364067 -0.23286903]
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 893941 895129
# 897353 897630
# 120448 2817
# 1231 802
# 484 353
# 200 146
# 106 51
# 40 27
# 0 0
# R0= [[ 9.99999999e-01  3.85462344e-05]
#  [-3.85462344e-05  9.99999999e-01]] t0= [15.51955633 -2.95801073]
# number_common_nodes_found : 326 [[ 9.99999770e-01 -6.77975428e-04]
#  [ 6.77975428e-04  9.99999770e-01]] [ 27.62856871 -10.55770763]
# number_common_nodes_found : 477 [[ 9.99999933e-01 -3.67403569e-04]
#  [ 3.67403569e-04  9.99999933e-01]] [10.01730787 -7.58418995]
# number_common_nodes_found : 489 [[ 9.99999994e-01 -1.13772386e-04]
#  [ 1.13772386e-04  9.99999994e-01]] [ 2.27709407 -2.3322625 ]
# number_common_nodes_found : 494 [[ 1.00000000e+00 -6.39545317e-06]
#  [ 6.39545317e-06  1.00000000e+00]] [ 0.15442945 -0.21257165]
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 914911 915845
# 918147 917942
# 122554 2439
# 895 593
# 328 166
# 144 126
# 126 115
# 115 104
# 105 56
# 54 40
# 42 32
# 38 28
# 34 24
# 22 12
# 13 8
# 3 1
# 0 0
# R0= [[ 0.99999932 -0.00116555]
#  [ 0.00116555  0.99999932]] t0= [ 40.0774001  -20.68673172]
# number_common_nodes_found : 110 [[ 9.99999744e-01  7.15343267e-04]
#  [-7.15343267e-04  9.99999744e-01]] [ 2.41793291 -1.45478621]
# number_common_nodes_found : 441 [[ 9.99999998e-01  6.93616731e-05]
#  [-6.93616731e-05  9.99999998e-01]] [ 4.45969157 -7.64436071]
# number_common_nodes_found : 485 [[ 1.00000000e+00 -2.36639511e-05]
#  [ 2.36639511e-05  1.00000000e+00]] [ 0.58285864 -1.24494936]
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 952263 953250
# 955991 955795
# 127745 3507
# 1741 1136
# 802 544
# 475 320
# 252 164
# 106 56
# 50 46
# 39 35
# 27 23
# 21 19
# 13 0
# 0 0
# R0= [[ 9.99999710e-01  7.61040977e-04]
#  [-7.61040977e-04  9.99999710e-01]] t0= [  7.46048313 -10.34409628]
#          1026843175 function calls (1026428392 primitive calls) in 1257.497 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        24    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(amax)
#        24    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(amin)
#     20627    0.014    0.000    0.412    0.000 <__array_function__ internals>:2(around)
#     12556    0.031    0.000    1.062    0.000 <__array_function__ internals>:2(concatenate)
#     37668    0.049    0.000    0.143    0.000 <__array_function__ internals>:2(copyto)
#     25388    0.021    0.000    0.165    0.000 <__array_function__ internals>:2(dot)
#      9468    0.025    0.000    0.754    0.000 <__array_function__ internals>:2(mean)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#      4725    0.011    0.000    0.162    0.000 <__array_function__ internals>:2(norm)
#     20627    0.013    0.000    0.451    0.000 <__array_function__ internals>:2(round_)
#         9    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(svd)
#     41272    0.026    0.000    0.105    0.000 <__array_function__ internals>:2(transpose)
#    427024    0.329    0.000    0.760    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#         9    0.309    0.034  131.273   14.586 <ipython-input-10-f22e66b98ebf>:1(find_common_group_nodes)
#     20624   62.663    0.003   62.663    0.003 <ipython-input-10-f22e66b98ebf>:11(<listcomp>)
#     20624   66.650    0.003   66.650    0.003 <ipython-input-10-f22e66b98ebf>:14(<listcomp>)
#      4716    0.018    0.000    0.018    0.000 <ipython-input-10-f22e66b98ebf>:18(<listcomp>)
#      4716    0.009    0.000    0.009    0.000 <ipython-input-10-f22e66b98ebf>:19(<listcomp>)
#         9    0.029    0.003    0.137    0.015 <ipython-input-10-f22e66b98ebf>:2(<listcomp>)
#         3    4.777    1.592 1255.790  418.597 <ipython-input-10-f22e66b98ebf>:27(realign2)
#         9    0.026    0.003    0.120    0.013 <ipython-input-10-f22e66b98ebf>:3(<listcomp>)
#         9    0.103    0.011    0.439    0.049 <ipython-input-10-f22e66b98ebf>:8(<dictcomp>)
#         3    2.516    0.839    5.340    1.780 <ipython-input-4-177392943169>:1(transform_skeleton)
#         1    0.462    0.462 1256.253 1256.253 <string>:1(<listcomp>)
#         1    1.245    1.245 1257.497 1257.497 <string>:1(<module>)
# 142946/142934    0.060    0.000    0.139    0.000 _asarray.py:14(asarray)
#     12559    0.100    0.000    0.210    0.000 _asarray.py:221(require)
#     12559    0.021    0.000    0.027    0.000 _asarray.py:298(<setcomp>)
#      9468    0.007    0.000    0.192    0.000 _asarray.py:86(asanyarray)
#    125602    0.066    0.000    0.066    0.000 _dtype.py:24(_kind_name)
#    125602    0.058    0.000    0.058    0.000 _dtype.py:307(_name_includes_bit_suffix)
#    125602    0.307    0.000    0.449    0.000 _dtype.py:321(_name_get)
#      9468    0.174    0.000    0.613    0.000 _methods.py:143(_mean)
#         3    0.000    0.000    0.000    0.000 _methods.py:45(_sum)
#         3    0.000    0.000    0.000    0.000 _methods.py:53(_any)
#     25109    0.018    0.000    0.262    0.000 _methods.py:56(_all)
#      9468    0.036    0.000    0.051    0.000 _methods.py:59(_count_reduce_items)
#        72    0.000    0.000    0.000    0.000 _ufunc_config.py:132(geterr)
#        72    0.000    0.000    0.001    0.000 _ufunc_config.py:32(seterr)
#        36    0.000    0.000    0.000    0.000 _ufunc_config.py:429(__init__)
#        36    0.000    0.000    0.000    0.000 _ufunc_config.py:433(__enter__)
#        36    0.000    0.000    0.000    0.000 _ufunc_config.py:438(__exit__)
#     25112    0.015    0.000    0.020    0.000 _validators.py:208(validate_bool_kwarg)
#    326525    0.126    0.000    0.384    0.000 abc.py:137(__instancecheck__)
#     12556    0.061    0.000    1.600    0.000 api.py:109(_get_combined_index)
#     12556    0.073    0.000    1.018    0.000 api.py:161(union_indexes)
#     12556    0.031    0.000    0.044    0.000 api.py:233(_sanitize_and_check)
#     12556    0.012    0.000    0.012    0.000 api.py:254(<setcomp>)
#     12556    0.034    0.000    0.173    0.000 api.py:271(get_consensus_names)
#     12556    0.049    0.000    0.134    0.000 api.py:289(<setcomp>)
#     12556    0.028    0.000    1.679    0.000 api.py:65(get_objs_combined_axis)
#     12556    0.020    0.000    0.051    0.000 api.py:91(<listcomp>)
#     12556    0.040    0.000    0.054    0.000 api.py:95(_get_distinct_objs)
#        24    0.000    0.000    0.007    0.000 arrayprint.py:1473(_array_str_implementation)
#        24    0.000    0.000    0.000    0.000 arrayprint.py:358(_get_formatdict)
#        24    0.000    0.000    0.004    0.000 arrayprint.py:366(<lambda>)
#        24    0.000    0.000    0.004    0.000 arrayprint.py:409(_get_format_function)
#        24    0.000    0.000    0.006    0.000 arrayprint.py:461(wrapper)
#        24    0.000    0.000    0.006    0.000 arrayprint.py:478(_array2string)
#        24    0.000    0.000    0.007    0.000 arrayprint.py:516(array2string)
#        24    0.000    0.000    0.000    0.000 arrayprint.py:60(_make_options_dict)
#        24    0.000    0.000    0.000    0.000 arrayprint.py:65(<dictcomp>)
#        72    0.000    0.000    0.000    0.000 arrayprint.py:695(_extendLine)
#        24    0.000    0.000    0.001    0.000 arrayprint.py:709(_formatArray)
#    120/24    0.001    0.000    0.001    0.000 arrayprint.py:718(recurser)
#        24    0.000    0.000    0.000    0.000 arrayprint.py:827(_none_or_positive_arg)
#        24    0.000    0.000    0.004    0.000 arrayprint.py:836(__init__)
#        24    0.001    0.000    0.004    0.000 arrayprint.py:863(fillFormat)
#        55    0.000    0.000    0.000    0.000 arrayprint.py:888(<genexpr>)
#        55    0.000    0.000    0.000    0.000 arrayprint.py:891(<genexpr>)
#        55    0.000    0.000    0.000    0.000 arrayprint.py:892(<genexpr>)
#        55    0.000    0.000    0.000    0.000 arrayprint.py:893(<genexpr>)
#        55    0.000    0.000    0.000    0.000 arrayprint.py:896(<genexpr>)
#        55    0.000    0.000    0.000    0.000 arrayprint.py:903(<genexpr>)
#        41    0.000    0.000    0.000    0.000 arrayprint.py:913(<genexpr>)
#        41    0.000    0.000    0.000    0.000 arrayprint.py:918(<genexpr>)
#        41    0.000    0.000    0.000    0.000 arrayprint.py:922(<genexpr>)
#        41    0.000    0.000    0.000    0.000 arrayprint.py:923(<genexpr>)
#        72    0.000    0.000    0.001    0.000 arrayprint.py:947(__call__)
#        12    0.000    0.000    0.000    0.000 base.py:1032(__iter__)
#     75339    0.018    0.000    0.018    0.000 base.py:1171(name)
#     25112    0.046    0.000    0.105    0.000 base.py:1178(name)
#     12556    0.038    0.000    0.074    0.000 base.py:1189(_validate_names)
#     37668    0.039    0.000    0.050    0.000 base.py:1209(_get_names)
#     12556    0.042    0.000    0.099    0.000 base.py:1212(_set_names)
#     12556    0.032    0.000    0.241    0.000 base.py:1242(set_names)
#     12556    0.004    0.000    0.004    0.000 base.py:1374(nlevels)
#         3    0.000    0.000    0.000    0.000 base.py:1716(is_integer)
#    138116    0.064    0.000    0.064    0.000 base.py:1751(is_floating)
#         6    0.000    0.000    0.000    0.000 base.py:1996(inferred_type)
#         6    0.004    0.001    0.004    0.001 base.py:2003(is_all_dates)
#    791262    0.533    0.000    2.296    0.000 base.py:256(is_dtype)
#    138116    0.142    0.000    0.527    0.000 base.py:2847(get_loc)
# 37689/12565    0.633    0.000    3.283    0.000 base.py:289(__new__)
#    100496    0.020    0.000    0.020    0.000 base.py:3866(_values)
#         3    0.000    0.000    0.000    0.000 base.py:3892(_get_engine_target)
#     37680    0.090    0.000    0.132    0.000 base.py:4079(__getitem__)
#    477320    0.432    0.000    0.582    0.000 base.py:413(find)
#     50233    0.206    0.000    1.795    0.000 base.py:4192(equals)
#     25112    0.013    0.000    0.015    0.000 base.py:420(<genexpr>)
#     37680    0.089    0.000    0.130    0.000 base.py:459(_simple_new)
#    138116    0.136    0.000    0.385    0.000 base.py:4619(_get_values_for_loc)
#     25115    0.060    0.000    0.154    0.000 base.py:494(_shallow_copy)
#    138116    0.119    0.000    0.273    0.000 base.py:4972(_maybe_cast_indexer)
#     50233    0.039    0.000    0.049    0.000 base.py:516(is_)
#     62792    0.035    0.000    0.035    0.000 base.py:540(_reset_identity)
#         3    0.000    0.000    0.000    0.000 base.py:550(_engine)
#    138143    0.074    0.000    0.095    0.000 base.py:5553(ensure_index)
#         3    0.000    0.000    0.000    0.000 base.py:557(<lambda>)
#    226071    0.113    0.000    0.140    0.000 base.py:563(__len__)
#     25112    0.069    0.000    0.669    0.000 base.py:5644(default_index)
#    125590    0.119    0.000    0.314    0.000 base.py:5650(maybe_extract_name)
#     12565    0.026    0.000    0.108    0.000 base.py:5666(_maybe_cast_with_dtype)
#     12565    0.059    0.000    0.392    0.000 base.py:5720(_maybe_cast_data_without_dtype)
#     12562    0.006    0.000    0.006    0.000 base.py:586(dtype)
#         3    0.000    0.000    0.000    0.000 base.py:637(ndim)
#         3    0.000    0.000    0.000    0.000 base.py:669(size)
#     12556    0.046    0.000    0.458    0.000 base.py:789(copy)
#     62798    0.212    0.000    0.802    0.000 blocks.py:123(__init__)
#     62798    0.043    0.000    0.043    0.000 blocks.py:134(_check_ndim)
#     12559    0.019    0.000    0.019    0.000 blocks.py:179(is_view)
#    150693    0.031    0.000    0.031    0.000 blocks.py:200(internal_values)
#         6    0.000    0.000    0.000    0.000 blocks.py:206(array_values)
#         9    0.000    0.000    0.000    0.000 blocks.py:212(get_values)
#    113031    0.033    0.000    0.033    0.000 blocks.py:232(mgr_locs)
#     62798    0.182    0.000    0.401    0.000 blocks.py:236(mgr_locs)
#     62792    0.122    0.000    0.931    0.000 blocks.py:2371(__init__)
#         3    0.000    0.000    0.000    0.000 blocks.py:2377(is_bool)
#         6    0.000    0.000    0.000    0.000 blocks.py:243(make_block)
#         3    0.000    0.000    0.000    0.000 blocks.py:2432(_can_hold_element)
#         3    0.000    0.000    0.000    0.000 blocks.py:255(make_block_same_class)
#    100472    0.556    0.000    3.024    0.000 blocks.py:2652(get_block_type)
#     62795    0.209    0.000    3.176    0.000 blocks.py:2698(make_block)
#         6    0.000    0.000    0.000    0.000 blocks.py:2725(_extend_blocks)
#         3    0.000    0.000    0.000    0.000 blocks.py:275(__len__)
#         3    0.000    0.000    0.000    0.000 blocks.py:286(_slice)
#     25115    0.013    0.000    0.013    0.000 blocks.py:310(shape)
#     37719    0.018    0.000    0.018    0.000 blocks.py:314(dtype)
#         3    0.000    0.000    0.000    0.000 blocks.py:339(apply)
#         3    0.000    0.000    0.000    0.000 blocks.py:349(_split_op_result)
#         3    0.000    0.000    0.000    0.000 blocks.py:781(setitem)
#     37680    0.228    0.000    0.390    0.000 cast.py:1180(maybe_castable)
#     75345    0.367    0.000    1.465    0.000 cast.py:1194(maybe_infer_to_datetimelike)
#     75348    0.461    0.000    2.190    0.000 cast.py:1303(maybe_cast_to_datetime)
#         6    0.000    0.000    0.000    0.000 cast.py:1523(construct_1d_arraylike_from_scalar)
#     50233    1.562    0.000    1.776    0.000 cast.py:1563(construct_1d_object_array_from_listlike)
#     37677    0.024    0.000    0.038    0.000 cast.py:1588(construct_1d_ndarray_preserving_na)
#     12556    0.051    0.000    0.061    0.000 cast.py:1724(validate_numeric_casting)
#     37668    0.103    0.000    2.826    0.000 cast.py:88(maybe_convert_platform)
#        15    0.000    0.000    0.000    0.000 common.py:1025(is_datetime_or_timedelta_dtype)
#        15    0.000    0.000    0.000    0.000 common.py:1180(needs_i8_conversion)
#     25112    0.019    0.000    0.068    0.000 common.py:1265(is_string_like_dtype)
#     25112    0.014    0.000    0.014    0.000 common.py:1293(<lambda>)
#     37701    0.039    0.000    0.091    0.000 common.py:1296(is_float_dtype)
#     25160    0.047    0.000    0.201    0.000 common.py:1330(is_bool_dtype)
#    477317    0.471    0.000    1.173    0.000 common.py:1460(is_extension_array_dtype)
#    175793    0.095    0.000    0.122    0.000 common.py:149(cast_scalar_indexer)
#     50224    0.048    0.000    0.057    0.000 common.py:150(ensure_python_int)
#     87895    0.078    0.000    1.307    0.000 common.py:1541(_is_dtype)
#    113055    0.078    0.000    0.119    0.000 common.py:1565(_get_dtype)
#    540109    0.463    0.000    0.866    0.000 common.py:1600(_is_dtype_type)
#    113055    0.086    0.000    0.126    0.000 common.py:1733(pandas_dtype)
#     12556    0.010    0.000    0.010    0.000 common.py:176(not_none)
#    439592    0.113    0.000    0.113    0.000 common.py:178(classes)
#     37668    0.009    0.000    0.009    0.000 common.py:180(<genexpr>)
#    439592    0.140    0.000    0.203    0.000 common.py:180(<lambda>)
#    100517    0.038    0.000    0.038    0.000 common.py:183(classes_and_not_datetimelike)
#    100517    0.039    0.000    0.053    0.000 common.py:188(<lambda>)
#     25112    0.046    0.000    0.075    0.000 common.py:190(all_none)
#     50224    0.016    0.000    0.016    0.000 common.py:194(<genexpr>)
#    364190    0.346    0.000    1.080    0.000 common.py:194(is_object_dtype)
#     25112    0.020    0.000    0.046    0.000 common.py:197(any_not_none)
#     50224    0.009    0.000    0.009    0.000 common.py:201(<genexpr>)
#     37689    0.114    0.000    0.380    0.000 common.py:218(asarray_tuplesafe)
#    150696    0.272    0.000    0.572    0.000 common.py:224(is_sparse)
#     37671    0.031    0.000    0.131    0.000 common.py:274(maybe_iterable_to_list)
#    150678    0.064    0.000    0.086    0.000 common.py:329(apply_if_callable)
#     25118    0.018    0.000    0.020    0.000 common.py:348(is_datetime64_dtype)
#    163279    0.122    0.000    0.617    0.000 common.py:381(is_datetime64tz_dtype)
#    100499    0.082    0.000    0.145    0.000 common.py:422(is_timedelta64_dtype)
#    238648    0.190    0.000    1.029    0.000 common.py:456(is_period_dtype)
#    238633    0.183    0.000    1.003    0.000 common.py:492(is_interval_dtype)
#    263751    0.202    0.000    0.911    0.000 common.py:530(is_categorical_dtype)
#     62783    0.081    0.000    1.339    0.000 common.py:566(is_string_dtype)
#     62783    0.058    0.000    1.163    0.000 common.py:595(condition)
#     62783    0.073    0.000    1.105    0.000 common.py:598(is_excluded_dtype)
#    251132    0.096    0.000    0.962    0.000 common.py:603(<genexpr>)
#     50257    0.085    0.000    0.186    0.000 common.py:696(is_integer_dtype)
#     25130    0.034    0.000    0.077    0.000 common.py:750(is_signed_integer_dtype)
#     25130    0.026    0.000    0.061    0.000 common.py:806(is_unsigned_integer_dtype)
#     75381    0.046    0.000    0.057    0.000 common.py:905(is_datetime64_any_dtype)
#         9    0.000    0.000    0.000    0.000 common.py:97(is_bool_indexer)
#     12556    0.112    0.000    1.853    0.000 concat.py:110(concat_compat)
#     25112    0.018    0.000    0.018    0.000 concat.py:128(is_nonempty)
#     12556    0.015    0.000    0.033    0.000 concat.py:139(<listcomp>)
#     25112    0.014    0.000    0.024    0.000 concat.py:144(<genexpr>)
#     12556    0.010    0.000    0.010    0.000 concat.py:147(<setcomp>)
#     37668    0.016    0.000    0.077    0.000 concat.py:148(<genexpr>)
#     25112    0.018    0.000    0.018    0.000 concat.py:174(__init__)
#         6    0.000    0.000    0.000    0.000 concat.py:185(needs_filling)
#         6    0.000    0.000    0.000    0.000 concat.py:194(dtype)
#     25112    0.180    0.000    3.192    0.000 concat.py:204(is_na)
#         6    0.000    0.000    0.000    0.000 concat.py:233(get_reindexed_values)
#     12556    0.102    0.000    0.509    0.000 concat.py:29(get_dtype_kinds)
#     12556    0.278    0.000    3.203    0.000 concat.py:295(__init__)
#         3    0.000    0.000    0.001    0.000 concat.py:306(_concatenate_join_units)
#     12556    0.165    0.000    6.795    0.001 concat.py:31(concatenate_block_managers)
#         3    0.000    0.000    0.000    0.000 concat.py:317(<listcomp>)
#         9    0.000    0.000    0.000    0.000 concat.py:332(<genexpr>)
#         3    0.000    0.000    0.000    0.000 concat.py:351(_get_empty_dtype_and_na)
#     12556    0.031    0.000    0.133    0.000 concat.py:380(<listcomp>)
#     12556    0.201    0.000    8.156    0.001 concat.py:456(get_result)
#     12556    0.045    0.000    3.385    0.000 concat.py:465(_is_uniform_join_units)
#     37668    0.019    0.000    0.019    0.000 concat.py:476(<genexpr>)
#     37665    0.077    0.000    3.269    0.000 concat.py:480(<genexpr>)
#     37659    0.011    0.000    0.011    0.000 concat.py:483(<genexpr>)
#     12556    0.026    0.000    0.302    0.000 concat.py:49(<listcomp>)
#         3    0.000    0.000    0.000    0.000 concat.py:490(_is_uniform_reindex)
#         6    0.000    0.000    0.000    0.000 concat.py:493(<genexpr>)
#     12556    0.011    0.000    0.022    0.000 concat.py:511(_get_result_dim)
#     12556    0.039    0.000    2.281    0.000 concat.py:517(_get_new_axes)
#     12556    0.032    0.000    2.220    0.000 concat.py:520(<listcomp>)
#     12556    0.034    0.000    1.724    0.000 concat.py:524(_get_comb_axis)
#     25112    0.151    0.000    0.210    0.000 concat.py:525(_combine_concat_plans)
#     12556    0.041    0.000    0.463    0.000 concat.py:534(_get_concat_axis)
#     50224    0.032    0.000    0.042    0.000 concat.py:550(_next_or_none)
#     12556    0.024    0.000    0.043    0.000 concat.py:567(<listcomp>)
#     37668    0.011    0.000    0.036    0.000 concat.py:570(<genexpr>)
#     12553    0.010    0.000    0.010    0.000 concat.py:66(<listcomp>)
#     12556    0.068    0.000   11.427    0.001 concat.py:70(concat)
#     25112    0.113    0.000    0.276    0.000 concat.py:87(_get_mgr_concatenation_plan)
#     12559    0.139    0.000   13.262    0.001 construction.py:237(init_dict)
#     12556    0.031    0.000    0.163    0.000 construction.py:274(<listcomp>)
#     12556    0.015    0.000    0.046    0.000 construction.py:278(<listcomp>)
#     12556    0.020    0.000    0.183    0.000 construction.py:281(<listcomp>)
#     12559    0.086    0.000    5.347    0.000 construction.py:329(_homogenize)
#     75357    0.068    0.000    0.298    0.000 construction.py:339(extract_array)
#     12559    0.130    0.000    0.583    0.000 construction.py:360(extract_index)
#     75351    0.605    0.000    8.684    0.000 construction.py:390(sanitize_array)
#     37680    0.184    0.000    2.113    0.000 construction.py:520(_try_cast)
#     37680    0.039    0.000    0.208    0.000 construction.py:580(is_empty_data)
#     12559    0.069    0.000    9.436    0.001 construction.py:60(arrays_to_mgr)
#         3    0.000    0.000    0.004    0.001 construction.py:600(create_series_with_explicit_dtype)
#    200950    0.213    0.000    0.793    0.000 dtypes.py:1116(is_dtype)
#    200965    0.206    0.000    0.810    0.000 dtypes.py:903(is_dtype)
#         3    6.081    2.027  255.095   85.032 extract_graph.py:119(from_sparse_to_graph)
#         3    0.035    0.012    2.072    0.691 extract_graph.py:174(generate_set_node)
#         3    0.157    0.052    9.128    3.043 extract_graph.py:181(generate_nx_graph)
#         3    0.378    0.126  264.601   88.200 extract_graph.py:234(generate_nx_graph_from_skeleton)
#     12556    3.655    0.000  178.683    0.014 extract_graph.py:32(order_pixel)
#   1947204  171.793    0.000  173.691    0.000 extract_graph.py:33(get_neighbours)
#         3   12.113    4.038   40.864   13.621 extract_graph.py:63(extract_branches)
#   1948379   19.546    0.000   21.460    0.000 extract_graph.py:64(get_neighbours)
#         3    4.560    1.520    4.560    1.520 extract_graph.py:85(<dictcomp>)
#         3    0.560    0.187    0.560    0.187 extract_graph.py:86(<dictcomp>)
#     12556    0.008    0.000    0.008    0.000 frame.py:421(_constructor)
#     25115    0.103    0.000   13.463    0.001 frame.py:441(__init__)
#     50224    0.035    0.000    0.035    0.000 frame.py:568(axes)
#     25112    0.042    0.000    0.094    0.000 frame.py:585(shape)
#     12556    0.078    0.000   11.567    0.001 frame.py:7609(append)
#     37677    0.159    0.000    6.899    0.000 frame.py:966(iterrows)
#        24    0.000    0.000    0.000    0.000 fromnumeric.py:2584(_amax_dispatcher)
#        24    0.000    0.000    0.000    0.000 fromnumeric.py:2589(amax)
#        24    0.000    0.000    0.000    0.000 fromnumeric.py:2709(_amin_dispatcher)
#        24    0.000    0.000    0.000    0.000 fromnumeric.py:2714(amin)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:3071(_ndim_dispatcher)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:3075(ndim)
#     41254    0.005    0.000    0.005    0.000 fromnumeric.py:3164(_around_dispatcher)
#     20627    0.014    0.000    0.384    0.000 fromnumeric.py:3168(around)
#      9468    0.003    0.000    0.003    0.000 fromnumeric.py:3265(_mean_dispatcher)
#      9468    0.094    0.000    0.708    0.000 fromnumeric.py:3269(mean)
#     20627    0.013    0.000    0.425    0.000 fromnumeric.py:3628(round_)
#     61899    0.031    0.000    0.407    0.000 fromnumeric.py:52(_wrapfunc)
#     41272    0.005    0.000    0.005    0.000 fromnumeric.py:597(_transpose_dispatcher)
#     41272    0.019    0.000    0.055    0.000 fromnumeric.py:601(transpose)
#        48    0.000    0.000    0.001    0.000 fromnumeric.py:70(_wrapreduction)
#        48    0.000    0.000    0.000    0.000 fromnumeric.py:71(<dictcomp>)
#     12556    0.023    0.000    0.028    0.000 frozen.py:66(__getitem__)
#         6    0.000    0.000    0.000    0.000 function.py:48(__call__)
#   3692466    1.201    0.000    1.601    0.000 generic.py:10(_check)
#         3    0.000    0.000    0.000    0.000 generic.py:11386(stat_func)
#         3    0.000    0.000    0.000    0.000 generic.py:11553(logical_func)
#         3    0.000    0.000    0.000    0.000 generic.py:1316(__invert__)
#     62798    0.179    0.000    0.179    0.000 generic.py:195(__init__)
#         9    0.000    0.000    0.000    0.000 generic.py:232(attrs)
#         6    0.000    0.000    0.000    0.000 generic.py:249(_validate_dtype)
#     12556    0.014    0.000    0.108    0.000 generic.py:3198(_is_cached)
#         3    0.000    0.000    0.000    0.000 generic.py:3210(_maybe_update_cacher)
#         3    0.000    0.000    0.000    0.000 generic.py:3247(_clear_item_cache)
#     12559    0.036    0.000    0.233    0.000 generic.py:3586(_check_is_chained_assignment_possible)
#         3    0.000    0.000    0.000    0.000 generic.py:3606(_check_setitem_copy)
#     62795    0.022    0.000    0.022    0.000 generic.py:365(_get_axis_number)
#     12559    0.026    0.000    0.089    0.000 generic.py:3739(_is_view)
#     25121    0.025    0.000    0.031    0.000 generic.py:377(_get_axis)
#     25112    0.026    0.000    0.032    0.000 generic.py:382(_get_block_manager_axis)
#     50224    0.027    0.000    0.051    0.000 generic.py:471(ndim)
#     12565    0.011    0.000    0.014    0.000 generic.py:5092(__finalize__)
#     50254    0.089    0.000    0.089    0.000 generic.py:5120(__getattr__)
#     62810    0.167    0.000    0.345    0.000 generic.py:5138(__setattr__)
#     25124    0.038    0.000    0.166    0.000 generic.py:5194(_protect_consolidate)
#     25124    0.029    0.000    0.196    0.000 generic.py:5205(_consolidate_inplace)
#     25124    0.035    0.000    0.123    0.000 generic.py:5208(f)
#     25112    0.047    0.000    0.263    0.000 generic.py:5213(_consolidate)
#         9    0.000    0.000    0.001    0.000 generic.py:5265(values)
#         3    0.000    0.000    0.001    0.000 generic.py:7057(isna)
#     61209    0.029    0.000    0.107    0.000 graph.py:1365(degree)
#         3    0.000    0.000    0.000    0.000 graph.py:290(__init__)
#        18    0.000    0.000    0.000    0.000 graph.py:388(__iter__)
#     12556    0.068    0.000    0.082    0.000 graph.py:884(add_edges_from)
#         3    0.000    0.000    0.000    0.000 indexers.py:117(check_setitem_lengths)
#         6    0.000    0.000    0.000    0.000 indexers.py:348(check_array_indexer)
#         3    0.000    0.000    0.000    0.000 indexers.py:52(is_list_like_indexer)
#         3    0.000    0.000    0.000    0.000 indexers.py:68(is_scalar_indexer)
#         3    0.000    0.000    0.000    0.000 indexers.py:91(is_empty_indexer)
#         3    0.000    0.000    0.000    0.000 indexing.py:100(iloc)
#         3    0.000    0.000    0.000    0.000 indexing.py:1133(_convert_to_indexer)
#         3    0.000    0.000    0.000    0.000 indexing.py:1523(_setitem_with_indexer)
#         6    0.000    0.000    0.001    0.000 indexing.py:2153(check_bool_indexer)
#         3    0.000    0.000    0.000    0.000 indexing.py:2200(convert_missing_indexer)
#         3    0.000    0.000    0.000    0.000 indexing.py:2243(is_nested_tuple)
#         3    0.000    0.000    0.000    0.000 indexing.py:237(loc)
#         3    0.000    0.000    0.000    0.000 indexing.py:588(_get_setitem_indexer)
#         3    0.000    0.000    0.000    0.000 indexing.py:627(_ensure_listlike_indexer)
#         3    0.000    0.000    0.001    0.000 indexing.py:661(__setitem__)
#         3    0.000    0.000    0.000    0.000 indexing.py:922(_has_valid_setitem_indexer)
#        12    0.000    0.000    0.000    0.000 inference.py:185(is_array_like)
#         6    0.000    0.000    0.000    0.000 inference.py:263(is_dict_like)
#        18    0.000    0.000    0.000    0.000 inference.py:289(<genexpr>)
#    175841    0.091    0.000    0.132    0.000 inference.py:322(is_hashable)
#       351    0.002    0.000    0.045    0.000 iostream.py:197(schedule)
#       292    0.000    0.000    0.001    0.000 iostream.py:310(_is_master_process)
#       292    0.000    0.000    0.008    0.000 iostream.py:323(_schedule_flush)
#       292    0.002    0.000    0.048    0.000 iostream.py:386(write)
#       351    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         9    0.000    0.000    0.000    0.000 linalg.py:102(get_linalg_error_extobj)
#         9    0.000    0.000    0.000    0.000 linalg.py:107(_makearray)
#      4743    0.005    0.000    0.006    0.000 linalg.py:112(isComplexType)
#        18    0.000    0.000    0.000    0.000 linalg.py:125(_realType)
#         9    0.000    0.000    0.000    0.000 linalg.py:135(_commonType)
#         9    0.000    0.000    0.000    0.000 linalg.py:1479(_svd_dispatcher)
#         9    0.001    0.000    0.001    0.000 linalg.py:1483(svd)
#         9    0.000    0.000    0.000    0.000 linalg.py:194(_assert_stacked_2d)
#      4725    0.002    0.000    0.002    0.000 linalg.py:2359(_norm_dispatcher)
#      4725    0.063    0.000    0.143    0.000 linalg.py:2363(norm)
#     25115    0.110    0.000    0.560    0.000 managers.py:132(__init__)
#     25115    0.038    0.000    0.071    0.000 managers.py:138(<listcomp>)
#     37683    0.069    0.000    0.077    0.000 managers.py:1532(__init__)
#         6    0.000    0.000    0.000    0.000 managers.py:1553(from_blocks)
#     37674    0.097    0.000    1.935    0.000 managers.py:1564(from_array)
#    163300    0.048    0.000    0.048    0.000 managers.py:1575(_block)
#         3    0.000    0.000    0.000    0.000 managers.py:1589(get_slice)
#         3    0.000    0.000    0.000    0.000 managers.py:1598(index)
#     12598    0.022    0.000    0.037    0.000 managers.py:1602(dtype)
#    150693    0.111    0.000    0.183    0.000 managers.py:1613(internal_values)
#         3    0.000    0.000    0.000    0.000 managers.py:1621(is_consolidated)
#     12559    0.092    0.000    3.421    0.000 managers.py:1675(create_block_manager_from_arrays)
#     37677    0.015    0.000    0.019    0.000 managers.py:1680(<genexpr>)
#     12559    0.408    0.000    2.927    0.000 managers.py:1715(form_blocks)
#     12559    0.040    0.000    1.172    0.000 managers.py:1812(_simple_blockify)
#     12559    0.122    0.000    0.264    0.000 managers.py:1843(_stack_arrays)
#     37677    0.035    0.000    0.094    0.000 managers.py:1846(_asarray_compat)
#     12559    0.010    0.000    0.022    0.000 managers.py:1852(_shape_compat)
#     50227    0.095    0.000    0.264    0.000 managers.py:212(shape)
#    150681    0.044    0.000    0.168    0.000 managers.py:214(<genexpr>)
#     75339    0.032    0.000    0.040    0.000 managers.py:216(ndim)
#     25121    0.014    0.000    0.017    0.000 managers.py:233(_is_single_block)
#     25118    0.011    0.000    0.011    0.000 managers.py:259(items)
#         3    0.000    0.000    0.000    0.000 managers.py:306(__len__)
#     25115    0.106    0.000    0.363    0.000 managers.py:321(_verify_integrity)
#     50230    0.024    0.000    0.036    0.000 managers.py:323(<genexpr>)
#         6    0.000    0.000    0.001    0.000 managers.py:366(apply)
#         6    0.000    0.000    0.000    0.000 managers.py:385(<dictcomp>)
#         3    0.000    0.000    0.000    0.000 managers.py:533(setitem)
#     37680    0.024    0.000    0.122    0.000 managers.py:675(is_consolidated)
#     25115    0.051    0.000    0.097    0.000 managers.py:683(_consolidate_check)
#     25115    0.031    0.000    0.041    0.000 managers.py:684(<listcomp>)
#     12559    0.039    0.000    0.064    0.000 managers.py:703(is_view)
#         9    0.000    0.000    0.000    0.000 managers.py:806(as_array)
#     25124    0.012    0.000    0.060    0.000 managers.py:961(consolidate)
#     12559    0.014    0.000    0.087    0.000 managers.py:977(_consolidate_inplace)
#     25112    0.063    0.000    2.549    0.000 missing.py:130(_isna)
#     25112    0.109    0.000    2.426    0.000 missing.py:193(_isna_ndarraylike)
#     25112    0.144    0.000    1.693    0.000 missing.py:235(_isna_string_dtype)
#     37671    0.119    0.000    1.162    0.000 missing.py:358(array_equivalent)
#     37671    0.080    0.000    0.173    0.000 missing.py:456(_array_equivalent_object)
#     25112    0.021    0.000    2.571    0.000 missing.py:47(isna)
#         3    0.000    0.000    0.000    0.000 missing.py:516(na_value_for_dtype)
#     37668    0.009    0.000    0.009    0.000 multiarray.py:1043(copyto)
#     12556    0.004    0.000    0.004    0.000 multiarray.py:143(concatenate)
#     25388    0.005    0.000    0.005    0.000 multiarray.py:706(dot)
#         3    0.000    0.000    0.000    0.000 nanops.py:1258(_maybe_null_out)
#         3    0.000    0.000    0.000    0.000 nanops.py:1290(check_below_min_count)
#         6    0.000    0.000    0.000    0.000 nanops.py:168(_get_fill_value)
#         6    0.000    0.000    0.000    0.000 nanops.py:193(_maybe_get_mask)
#         6    0.000    0.000    0.000    0.000 nanops.py:237(_get_values)
#         6    0.000    0.000    0.000    0.000 nanops.py:322(_na_ok_dtype)
#         3    0.000    0.000    0.000    0.000 nanops.py:328(_wrap_results)
#         3    0.000    0.000    0.000    0.000 nanops.py:396(nanany)
#         3    0.000    0.000    0.000    0.000 nanops.py:470(nansum)
#         9    0.000    0.000    0.000    0.000 nanops.py:57(check)
#         3    0.000    0.000    0.000    0.000 nanops.py:61(_f)
#        12    0.000    0.000    0.000    0.000 nanops.py:64(<genexpr>)
#         3    0.000    0.000    0.000    0.000 numeric.py:2084(identity)
#     37668    0.098    0.000    0.324    0.000 numeric.py:268(full)
#     25112    0.009    0.000    0.009    0.000 numeric.py:81(_validate_dtype)
#         6    0.000    0.000    0.000    0.000 numpy_.py:162(__init__)
#         6    0.000    0.000    0.000    0.000 numpy_.py:210(__array__)
#         6    0.000    0.000    0.000    0.000 numpy_.py:50(__init__)
#     25112    0.064    0.000    0.197    0.000 range.py:134(_simple_new)
#        27    0.000    0.000    0.000    0.000 range.py:153(_data)
#         3    0.000    0.000    0.000    0.000 range.py:214(start)
#         3    0.000    0.000    0.000    0.000 range.py:237(stop)
#         3    0.000    0.000    0.000    0.000 range.py:260(step)
#    138107    0.060    0.000    0.083    0.000 range.py:687(__len__)
#     25112    0.149    0.000    0.559    0.000 range.py:86(__new__)
#     61209    0.061    0.000    0.078    0.000 reportviews.py:344(__init__)
#     61209    0.037    0.000    0.094    0.000 reportviews.py:351(__call__)
#     61209    0.051    0.000    0.057    0.000 reportviews.py:445(__getitem__)
#     12556    0.113    0.000    0.303    0.000 series.py:1031(_set_with_engine)
#         3    0.000    0.000    0.000    0.000 series.py:1097(_is_mixed_type)
# 37683/37680    0.410    0.000    6.746    0.000 series.py:201(__init__)
#         3    0.000    0.000    0.005    0.002 series.py:335(_init_dict)
#         9    0.000    0.000    0.000    0.000 series.py:381(_constructor)
#     37677    0.053    0.000    0.056    0.000 series.py:398(_set_axis)
#         6    0.000    0.000    0.001    0.000 series.py:4211(_reduce)
#     12598    0.016    0.000    0.052    0.000 series.py:427(dtype)
#     37695    0.063    0.000    0.113    0.000 series.py:442(name)
#         3    0.000    0.000    0.001    0.000 series.py:4793(isna)
#     37692    0.038    0.000    0.065    0.000 series.py:492(name)
#    150693    0.077    0.000    0.261    0.000 series.py:540(_values)
#         6    0.000    0.000    0.000    0.000 series.py:574(array)
#         3    0.000    0.000    0.000    0.000 series.py:595(__len__)
#         6    0.000    0.000    0.000    0.000 series.py:750(__array__)
#    138119    0.307    0.000    1.575    0.000 series.py:868(__getitem__)
#         3    0.000    0.000    0.000    0.000 series.py:966(_get_values)
#    138116    0.203    0.000    1.114    0.000 series.py:974(_get_value)
#     12556    0.074    0.000    0.625    0.000 series.py:994(__setitem__)
#       351    0.041    0.000    0.041    0.000 socket.py:357(send)
#  81832509  354.414    0.000  361.936    0.000 sparse_util.py:122(neighbours)
#  60797251   57.450    0.000  231.822    0.000 sparse_util.py:130(transitions)
# 547175259   99.061    0.000   99.061    0.000 sparse_util.py:133(<genexpr>)
#         3  129.343   43.114  771.215  257.072 sparse_util.py:135(zhangSuen)
#         3   11.719    3.906   11.719    3.906 sparse_util.py:137(<dictcomp>)
#         6   78.547   13.091   78.547   13.091 sparse_util.py:2(dilate)
#       351    0.000    0.000    0.001    0.000 threading.py:1050(_wait_for_tstate_lock)
#       351    0.001    0.000    0.002    0.000 threading.py:1092(is_alive)
#       351    0.000    0.000    0.000    0.000 threading.py:507(is_set)
#         3    0.000    0.000    0.000    0.000 twodim_base.py:152(eye)
#     62792    0.028    0.000    0.028    0.000 {built-in method __new__ of type object at 0x00007FF8976979A0}
#    326525    0.258    0.000    0.258    0.000 {built-in method _abc._abc_instancecheck}
#         3    0.000    0.000    0.000    0.000 {built-in method _operator.invert}
#        24    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#     87901    0.078    0.000    3.413    0.000 {built-in method builtins.all}
#    113013    0.108    0.000    1.181    0.000 {built-in method builtins.any}
#    150684    0.022    0.000    0.022    0.000 {built-in method builtins.callable}
#         1    0.000    0.000 1257.497 1257.497 {built-in method builtins.exec}
#   5462515    0.692    0.000    0.731    0.000 {built-in method builtins.getattr}
#    963955    0.476    0.000    0.476    0.000 {built-in method builtins.hasattr}
#    175841    0.040    0.000    0.040    0.000 {built-in method builtins.hash}
#     50248    0.006    0.000    0.006    0.000 {built-in method builtins.id}
#   7731177    2.176    0.000    3.874    0.000 {built-in method builtins.isinstance}
#   1978509    0.258    0.000    0.258    0.000 {built-in method builtins.issubclass}
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 5959308/5595124    0.911    0.000    1.084    0.000 {built-in method builtins.len}
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#     37763    0.017    0.000    0.017    0.000 {built-in method builtins.max}
#     12556    0.008    0.000    0.008    0.000 {built-in method builtins.min}
#     50224    0.009    0.000    0.009    0.000 {built-in method builtins.next}
#        70    0.001    0.000    0.057    0.001 {built-in method builtins.print}
#         3    0.012    0.004    0.012    0.004 {built-in method builtins.sorted}
# 142692543  103.572    0.000  202.705    0.000 {built-in method builtins.sum}
#       292    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#     12562    0.072    0.000    0.072    0.000 {built-in method numpy.arange}
# 373991/373979    3.012    0.000    3.012    0.000 {built-in method numpy.array}
#        56    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.dragon4_positional}
#        88    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.dragon4_scientific}
# 172391/147039    1.316    0.000    2.593    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#      9468    0.007    0.000    0.007    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#    125581    0.323    0.000    0.323    0.000 {built-in method numpy.empty}
#       144    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#        72    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         3    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_bool_array}
#         6    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_datetime_array}
#     25112    1.405    0.000    1.405    0.000 {built-in method pandas._libs.missing.isnaobj}
#     12556    0.002    0.000    0.002    0.000 {function FrozenList.__getitem__ at 0x000001F0010453A8}
#        18    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#       351    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#   5918714    0.690    0.000    0.690    0.000 {method 'add' of 'set' objects}
#     25109    0.031    0.000    0.292    0.000 {method 'all' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#       351    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#  19454903    2.651    0.000    2.651    0.000 {method 'append' of 'list' objects}
#     45766    0.082    0.000    0.082    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#     25136    0.010    0.000    0.010    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#  16353435    4.267    0.000    4.267    0.000 {method 'discard' of 'set' objects}
#     12559    0.003    0.000    0.003    0.000 {method 'extend' of 'list' objects}
#         9    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#     12574    0.005    0.000    0.005    0.000 {method 'get' of 'dict' objects}
#    150672    0.158    0.000    0.158    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#     25112    3.678    0.000    3.678    0.000 {method 'index' of 'list' objects}
#     25184    0.006    0.000    0.006    0.000 {method 'items' of 'dict' objects}
#  83808179    7.733    0.000    7.733    0.000 {method 'keys' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#        44    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#  11460240    6.488    0.000    6.488    0.000 {method 'pop' of 'dict' objects}
#   3895583    0.507    0.000    0.507    0.000 {method 'pop' of 'set' objects}
#    130297    0.083    0.000    0.083    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     34631    0.434    0.000    0.434    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     25112    0.026    0.000    0.026    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#     20627    0.356    0.000    0.356    0.000 {method 'round' of 'numpy.ndarray' objects}
#        48    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#        72    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#     12562    0.011    0.000    0.011    0.000 {method 'startswith' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#     41281    0.010    0.000    0.010    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#   3875764    0.752    0.000    0.752    0.000 {method 'union' of 'set' objects}
#     25139    0.008    0.000    0.008    0.000 {method 'update' of 'dict' objects}
#     12559    0.005    0.000    0.005    0.000 {method 'upper' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#    150684    0.045    0.000    0.045    0.000 {pandas._libs.algos.ensure_object}
#     37671    0.044    0.000    0.044    0.000 {pandas._libs.lib.array_equivalent_object}
#         6    0.000    0.000    0.000    0.000 {pandas._libs.lib.clean_index_list}
#     75336    0.069    0.000    0.069    0.000 {pandas._libs.lib.infer_datetimelike_array}
#     87916    0.938    0.000    1.225    0.000 {pandas._libs.lib.infer_dtype}
#     25112    0.006    0.000    0.006    0.000 {pandas._libs.lib.is_bool}
#    175793    0.027    0.000    0.027    0.000 {pandas._libs.lib.is_float}
#    276238    0.039    0.000    0.039    0.000 {pandas._libs.lib.is_integer}
#     12568    0.005    0.000    0.005    0.000 {pandas._libs.lib.is_iterator}
#    238624    0.248    0.000    0.535    0.000 {pandas._libs.lib.is_list_like}
#    263715    0.060    0.000    0.060    0.000 {pandas._libs.lib.is_scalar}
#     37668    0.766    0.000    1.090    0.000 {pandas._libs.lib.maybe_convert_objects}
